# %% [markdown]
# # Import Libs and DataFrames

# %%
import pandas as pd


df_trn = pd.read_csv("../data/dados_projeto_evasao_treino.csv")
df_tst = pd.read_csv("../data/dados_projeto_evasao_teste.csv")

# %% [markdown]
# # Dados iniciai

# %% [markdown]
# ## DataFrames

# %% [markdown]
# ### Treino

# %%
df_trn
# Out:
#      Unnamed: 0 ds_cidade_usuario  ts_primeiro_acesso  ts_ultimo_acesso  \
# 0             1          Campinas                   0                 0
# 1             3          Campinas                   0                 0
# 2             4          Campinas                   0                 0
# 3             5               NaN          1692744534        1693928454
# 4             6          Campinas                   0                 0
# ..          ...               ...                 ...               ...
# 395         492          curitiba          1668077732        1668083176
# 396         493          Campinas                   0                 0
# 397         496          Campinas          1691607939        1691608000
# 398         498          Campinas                   0                 0
# 399         499          Campinas                   0                 0
#
#      nr_dias_desde_primeiro_acesso  nr_dias_desde_ultimo_acesso  \
# ...

# %% [markdown]
# ## info

# %%
print(df_trn.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 37 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Unnamed: 0                            400 non-null    int64
#  1   ds_cidade_usuario                     346 non-null    object
#  2   ts_primeiro_acesso                    400 non-null    int64
#  3   ts_ultimo_acesso                      400 non-null    int64
#  4   nr_dias_desde_primeiro_acesso         400 non-null    int64
#  5   nr_dias_desde_ultimo_acesso           400 non-null    int64
#  6   nr_atividades_sinalizadas             400 non-null    int64
#  7   nr_atividades_mapeadas                400 non-null    int64
#  8   nr_discussoes_forum_postadas          400 non-null    int64
#  9   nr_questionarios_abandonados          400 non-null    int64
#  10  nr_questionarios_finalizados          400 non-null    int64
# ...

# %% [markdown]
# ## describe

# %%
print(df_trn.describe())
# Out:
#        Unnamed: 0  ts_primeiro_acesso  ts_ultimo_acesso  \
# count  400.000000        4.000000e+02      4.000000e+02
# mean   248.027500        8.647958e+08      8.664560e+08
# std    140.580382        8.445285e+08      8.461345e+08
# min      1.000000        0.000000e+00      0.000000e+00
# 25%    131.500000        0.000000e+00      0.000000e+00
# 50%    245.500000        1.661414e+09      1.666093e+09
# 75%    367.250000        1.692747e+09      1.693434e+09
# max    499.000000        1.694097e+09      1.694471e+09
#
#        nr_dias_desde_primeiro_acesso  nr_dias_desde_ultimo_acesso  \
# count                     400.000000                   400.000000
# mean                     9602.667500                  9583.465000
# std                      9774.754241                  9793.330251
# min                         4.000000                     0.000000
# 25%                        20.000000                    12.000000
# ...

# %% [markdown]
# ## columns

# %%
print(df_trn.columns)
# Out:
# Index(['Unnamed: 0', 'ds_cidade_usuario', 'ts_primeiro_acesso',
#        'ts_ultimo_acesso', 'nr_dias_desde_primeiro_acesso',
#        'nr_dias_desde_ultimo_acesso', 'nr_atividades_sinalizadas',
#        'nr_atividades_mapeadas', 'nr_discussoes_forum_postadas',
#        'nr_questionarios_abandonados', 'nr_questionarios_finalizados',
#        'vl_medio_tempo_questionario', 'vl_medio_tempo_questionario_avaliado',
#        'vl_desempenho_questionario', 'nr_intervalos_uso', 'nr_dias_uso',
#        'vl_medio_atividade_diaria', 'vl_engajamento_usuario_por_intervalo',
#        'vl_engajamento_usuario_intradia', 'nr_interacoes_usuario',
#        'nr_dias_engajamento_discussao', 'nr_dias_engajamento_questionario',
#        'nr_engajamento_discussao', 'nr_engajamento_questionario',
#        'nr_questoes_respondidas', 'nr_questoes_corretas',
#        'nr_questoes_erradas', 'nr_questoes_parciais', 'vl_desempenho_usuario',
#        'vl_media_questoes_por_dia', 'vl_engajamento_notas',
# ...

# %% [markdown]
# ### Teste

# %%
print(df_trn.columns)
# Out:
# Index(['Unnamed: 0', 'ds_cidade_usuario', 'ts_primeiro_acesso',
#        'ts_ultimo_acesso', 'nr_dias_desde_primeiro_acesso',
#        'nr_dias_desde_ultimo_acesso', 'nr_atividades_sinalizadas',
#        'nr_atividades_mapeadas', 'nr_discussoes_forum_postadas',
#        'nr_questionarios_abandonados', 'nr_questionarios_finalizados',
#        'vl_medio_tempo_questionario', 'vl_medio_tempo_questionario_avaliado',
#        'vl_desempenho_questionario', 'nr_intervalos_uso', 'nr_dias_uso',
#        'vl_medio_atividade_diaria', 'vl_engajamento_usuario_por_intervalo',
#        'vl_engajamento_usuario_intradia', 'nr_interacoes_usuario',
#        'nr_dias_engajamento_discussao', 'nr_dias_engajamento_questionario',
#        'nr_engajamento_discussao', 'nr_engajamento_questionario',
#        'nr_questoes_respondidas', 'nr_questoes_corretas',
#        'nr_questoes_erradas', 'nr_questoes_parciais', 'vl_desempenho_usuario',
#        'vl_media_questoes_por_dia', 'vl_engajamento_notas',
# ...

# %%
df_tst
# Out:
#     Unnamed: 0 ds_cidade_usuario  ts_primeiro_acesso  ts_ultimo_acesso  \
# 0          361          Campinas          1693227920        1693228016
# 1           73          Holambra          1661542019        1662149939
# 2          374          Campinas          1693578285        1694298462
# 3          155          Campinas          1690827091        1690827413
# 4          104          Campinas                   0                 0
# ..         ...               ...                 ...               ...
# 95         347               NaN          1690662696        1690662696
# 96          86               NaN          1693428019        1694470591
# 97          75          Campinas                   0                 0
# 98         438          Campinas                   0                 0
# 99          15          Campinas                   0                 0
#
#     nr_dias_desde_primeiro_acesso  nr_dias_desde_ultimo_acesso  \
# ...

# %% [markdown]
# # Removendo colunas não relevantes

# %%
df_trn = df_trn.loc[:, ~df_trn.columns.str.contains('^Unnamed')]
df_tst = df_tst.loc[:, ~df_tst.columns.str.contains('^Unnamed')]

# %%
limite_nulos = len(df_trn) * 0.2
df_trn = df_trn.dropna(thresh=limite_nulos, axis=1)

limite_nulos = len(df_tst) * 0.2
df_tst = df_tst.dropna(thresh=limite_nulos, axis=1)

# %% [markdown]
# # Convertendo timeStamps

# %%
df_trn['ts_primeiro_acesso'] = pd.to_datetime(df_trn['ts_primeiro_acesso'], unit='s', errors='coerce')
df_trn['ts_ultimo_acesso'] = pd.to_datetime(df_trn['ts_ultimo_acesso'], unit='s', errors='coerce')

df_tst['ts_primeiro_acesso'] = pd.to_datetime(df_tst['ts_primeiro_acesso'], unit='s', errors='coerce')
df_tst['ts_ultimo_acesso'] = pd.to_datetime(df_tst['ts_ultimo_acesso'], unit='s', errors='coerce')

# %%
df_trn = df_trn.rename(columns={
    'ts_primeiro_acesso': 'dt_primeiro_acesso',
    'ts_ultimo_acesso': 'dt_ultimo_acesso'
})

df_tst = df_tst.rename(columns={
    'ts_primeiro_acesso': 'dt_primeiro_acesso',
    'ts_ultimo_acesso': 'dt_ultimo_acesso'
})

# %% [markdown]
# # Tratando valores faltantes

# %%
print(df_trn.isnull().sum())
# Out:
# ds_cidade_usuario                        54
# dt_primeiro_acesso                        0
# dt_ultimo_acesso                          0
# nr_dias_desde_primeiro_acesso             0
# nr_dias_desde_ultimo_acesso               0
# nr_atividades_sinalizadas                 0
# nr_atividades_mapeadas                    0
# nr_discussoes_forum_postadas              0
# nr_questionarios_abandonados              0
# nr_questionarios_finalizados              0
# vl_medio_tempo_questionario             289
# vl_medio_tempo_questionario_avaliado    293
# nr_intervalos_uso                       191
# nr_dias_uso                               0
# vl_medio_atividade_diaria               191
# nr_interacoes_usuario                     0
# nr_dias_engajamento_discussao             0
# nr_dias_engajamento_questionario          0
# nr_engajamento_discussao                  0
# nr_engajamento_questionario               0
# nr_questoes_respondidas                   0
# ...

# %%
df_trn = df_trn.fillna(0)
df_tst = df_tst.fillna(0)

# %% [markdown]
# # Removendo dados Duplicados

# %%
print(df_trn.duplicated().sum())
# Out:
# 307

# %%
print(f"Antes: {len(df_trn)} linhas")

print(f"Antes: {len(df_tst)} linhas")
# Out:
# Antes: 400 linhas
# Antes: 100 linhas

# %%
df_trn = df_trn.drop_duplicates(keep='last')

df_tst = df_tst.drop_duplicates(keep='last')

# %%
print(f"Depois: {len(df_trn)} linhas")

print(f"Depois: {len(df_tst)} linhas")
# Out:
# Depois: 93 linhas
# Depois: 38 linhas

# %% [markdown]
# # Ajustando data invalidadas

# %%
df_trn = df_trn[df_trn['dt_primeiro_acesso'].dt.year != 1970]
df_trn = df_trn[df_trn['dt_ultimo_acesso'].dt.year != 1970]

df_tst = df_tst[df_tst['dt_primeiro_acesso'].dt.year != 1970]
df_tst = df_tst[df_tst['dt_ultimo_acesso'].dt.year != 1970]

# %% [markdown]
# # Supondo que alunos que não entram a mais de 90 dias fora do periodo de ferias abandonaram

# %%
meses_ferias = [1, 2, 7, 12]

def verificar_abandono(row):
    ultimo_acesso = row['dt_ultimo_acesso']
    dias_sem_acesso = row['nr_dias_desde_ultimo_acesso']

    if ultimo_acesso.month in meses_ferias:
        return 0
    elif dias_sem_acesso > 90:
        return 1
    else:
        return 0
    
df_trn['abandono'] = df_trn.apply(verificar_abandono, axis=1)
df_tst['abandono'] = df_tst.apply(verificar_abandono, axis=1)

# %% [markdown]
# # removendo colunas não mais nescessarias

# %%
colunas_remover = ['dt_primeiro_acesso', 'dt_ultimo_acesso', 'ds_cidade_usuario']
df_trn = df_trn.drop(columns=colunas_remover)
df_tst = df_tst.drop(columns=colunas_remover)

# %% [markdown]
# # Revisando dados

# %%
df_trn
# Out:
#      nr_dias_desde_primeiro_acesso  nr_dias_desde_ultimo_acesso  \
# 3                               20                            6
# 7                               19                           18
# 26                              34                           34
# 29                              20                            5
# 31                              20                           20
# ..                             ...                          ...
# 391                            220                           12
# 392                             12                            1
# 394                              4                            0
# 395                            305                          305
# 397                             33                           33
#
#      nr_atividades_sinalizadas  nr_atividades_mapeadas  \
# 3                            0                       4
# 7                            0                       0
# ...

# %%
print(df_trn.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 3 to 397
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   nr_dias_desde_primeiro_acesso         90 non-null     int64
#  1   nr_dias_desde_ultimo_acesso           90 non-null     int64
#  2   nr_atividades_sinalizadas             90 non-null     int64
#  3   nr_atividades_mapeadas                90 non-null     int64
#  4   nr_discussoes_forum_postadas          90 non-null     int64
#  5   nr_questionarios_abandonados          90 non-null     int64
#  6   nr_questionarios_finalizados          90 non-null     int64
#  7   vl_medio_tempo_questionario           90 non-null     float64
#  8   vl_medio_tempo_questionario_avaliado  90 non-null     float64
#  9   nr_intervalos_uso                     90 non-null     float64
#  10  nr_dias_uso                           90 non-null     int64
# ...

# %%
df_trn
# Out:
#      nr_dias_desde_primeiro_acesso  nr_dias_desde_ultimo_acesso  \
# 3                               20                            6
# 7                               19                           18
# 26                              34                           34
# 29                              20                            5
# 31                              20                           20
# ..                             ...                          ...
# 391                            220                           12
# 392                             12                            1
# 394                              4                            0
# 395                            305                          305
# 397                             33                           33
#
#      nr_atividades_sinalizadas  nr_atividades_mapeadas  \
# 3                            0                       4
# 7                            0                       0
# ...

# %%
print(df_trn.describe())
# Out:
#        nr_dias_desde_primeiro_acesso  nr_dias_desde_ultimo_acesso  \
# count                      90.000000                    90.000000
# mean                       81.466667                    45.233333
# std                       118.896348                    85.249673
# min                         4.000000                     0.000000
# 25%                        12.000000                     6.000000
# 50%                        21.000000                    13.000000
# 75%                        54.000000                    26.750000
# max                       390.000000                   353.000000
#
#        nr_atividades_sinalizadas  nr_atividades_mapeadas  \
# count                  90.000000               90.000000
# mean                    0.188889                1.855556
# std                     1.271065                7.191695
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# ...

# %%
print(df_trn.dtypes)
# Out:
# nr_dias_desde_primeiro_acesso             int64
# nr_dias_desde_ultimo_acesso               int64
# nr_atividades_sinalizadas                 int64
# nr_atividades_mapeadas                    int64
# nr_discussoes_forum_postadas              int64
# nr_questionarios_abandonados              int64
# nr_questionarios_finalizados              int64
# vl_medio_tempo_questionario             float64
# vl_medio_tempo_questionario_avaliado    float64
# nr_intervalos_uso                       float64
# nr_dias_uso                               int64
# vl_medio_atividade_diaria               float64
# nr_interacoes_usuario                     int64
# nr_dias_engajamento_discussao             int64
# nr_dias_engajamento_questionario          int64
# nr_engajamento_discussao                  int64
# nr_engajamento_questionario               int64
# nr_questoes_respondidas                   int64
# nr_questoes_corretas                      int64
# nr_questoes_erradas                       int64
# ...

# %%
print(df_trn.isnull().sum())
# Out:
# nr_dias_desde_primeiro_acesso           0
# nr_dias_desde_ultimo_acesso             0
# nr_atividades_sinalizadas               0
# nr_atividades_mapeadas                  0
# nr_discussoes_forum_postadas            0
# nr_questionarios_abandonados            0
# nr_questionarios_finalizados            0
# vl_medio_tempo_questionario             0
# vl_medio_tempo_questionario_avaliado    0
# nr_intervalos_uso                       0
# nr_dias_uso                             0
# vl_medio_atividade_diaria               0
# nr_interacoes_usuario                   0
# nr_dias_engajamento_discussao           0
# nr_dias_engajamento_questionario        0
# nr_engajamento_discussao                0
# nr_engajamento_questionario             0
# nr_questoes_respondidas                 0
# nr_questoes_corretas                    0
# nr_questoes_erradas                     0
# nr_questoes_parciais                    0
# vl_desempenho_usuario                   0
# ...

# %% [markdown]
# # Salvando Copia dados limpos

# %%
df_trn.to_csv('../data/gui_dados_limpos_treino.csv', index=False)
df_tst.to_csv('../data/gui_dados_limpos_teste.csv', index=False)
